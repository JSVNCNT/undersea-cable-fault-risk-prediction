# %% [markdown]
# # 03 — Exploratory analysis
# Generated EDA tables and figures describe the supplied synthetic records without causal claims.

# %%
import pandas as pd
display(pd.read_csv('outputs/tables/eda/descriptive_statistics.csv'))
