# %% [markdown]
# # 08 — Final analysis
# This notebook summarizes generated artifacts and retains synthetic-data limitations and final-test status.

# %%
from pathlib import Path
print(Path('outputs/metrics/model_selection.json'))
