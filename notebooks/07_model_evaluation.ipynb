# %% [markdown]
# # 07 — Model evaluation
# Development validation is available; final test scoring is locked until explicit Final-Term authorization.

# %%
from src.evaluation import final_test_guard
try:
    final_test_guard(False)
except PermissionError as exc:
    print(exc)
