# %% [markdown]
# # 02 — Data cleaning
# Cleaning is executed reproducibly by `scripts/run_pipeline.py`; raw files are never overwritten.

# %%
from pathlib import Path
print(Path('data/processed/undersea_cables_cleaned.csv'))
