# %% [markdown]
# # 04 — Statistical analysis
# Association tests and assumption records are generated under `outputs/tables/statistics`.

# %%
import pandas as pd
display(pd.read_csv('outputs/tables/statistics/categorical_associations.csv'))
display(pd.read_csv('outputs/tables/statistics/numeric_comparisons.csv'))
