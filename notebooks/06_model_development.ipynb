# %% [markdown]
# # 06 — Model development
# The four approved candidates are compared on the chronological validation partition only.

# %%
import pandas as pd
display(pd.read_csv('outputs/tables/model_comparison_validation.csv'))
