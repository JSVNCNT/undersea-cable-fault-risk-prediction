# %% [markdown]
# # 01 — Source and data audit
# The source is synthetic; this notebook performs reproducible audit checks.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))
from src.data_loading import load_master_data
from src.data_validation import audit_master
df=load_master_data()
summary,gaps,target,variables=audit_master(df)
display(summary)
display(gaps)
